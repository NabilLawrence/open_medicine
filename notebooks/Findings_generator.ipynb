# %%
import numpy as np
import pandas as pd
import re

# %%
df = pd.read_csv("../data/UpperGI.csv")

# %%
df = df.rename({"out": "text"}, axis=1)

# %%
def regex_indications(string):
    hospital_reg = r"\.*INDICATIONS FOR PROCEDURE:.*"
    line = re.findall(hospital_reg, string)[0]
    retrn_string =  line.replace(',',':').split(":")[1]
    if retrn_string[-1:] == "\r":
        retrn_string= retrn_string[:-1]
    if retrn_string[-8:] == "FINDINGS":
        return retrn_string[:-8]
    else:
        return retrn_string
    
df["indications"] = df['text'].apply(regex_indications)

# %%
def regex_extent(string):
    hospital_reg = r"\.*Extent of Exam:.*"
    line = re.findall(hospital_reg, string)[0]
    retrn_string =  line.replace(',',':').split(":")[1]
    if retrn_string[-1:] == "\r":
        return retrn_string[:-1]
    else:
        return retrn_string
df["extent_of_exam"] = df['text'].apply(regex_extent)

# %%
def regex_findings(string):
    hospital_reg = r"\.*FINDINGS:.*"
    line = re.findall(hospital_reg, string)[0][10:]
    return line
df["findings"] = df['text'].apply(regex_findings)

# %%
from transformers import pipeline

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
# Out:
# 2023-03-10 11:19:39.617521: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-10 11:19:40.817522: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-03-10 11:19:40.817700: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-03-10 11:19:40.817715: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
tokenizer = AutoTokenizer.from_pretrained("microsoft/biogpt")

model = AutoModelForCausalLM.from_pretrained("microsoft/biogpt")

# %%
generator_untrained = pipeline('text-generation', model=model, tokenizer=tokenizer)

# %%
generator_untrained("FINDINGS:", max_new_tokens = 30)
# Out:
# [{'generated_text': 'FINDINGS: The results of this study suggest that the use of a combination of the two methods of analysis is a useful approach to the study of the relationship between the'}]

# %%
def tokenize_function(example):
    return tokenizer(example['all'], padding="max_length", truncation=True, return_tensors="pt")

# %%
import datasets

# %%
from datasets import load_dataset

# %%
df['token'] = df.findings.map(tokenize_function)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_30473/3980281092.py in <module>
# ----> 1 df['token'] = df.findings.map(tokenize_function)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    4159         dtype: object
#    4160         """
# -> 4161         new_values = super()._map_values(arg, na_action=na_action)
#    4162         return self._constructor(new_values, index=self.index).__finalize__(
#    4163             self, method="map"
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#     868
#     869         # mapper is a function
# --> 870         new_values = map_f(values, mapper)
#     871
#     872         return new_values
#
# /opt/conda/lib/python3.7/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipykernel_30473/241531118.py in tokenize_function(example)
#       1 def tokenize_function(example):
# ----> 2     return tokenizer(example['all'], padding="max_length", truncation=True, return_tensors="pt")
#
# TypeError: string indices must be integers

# %%
new_data = df.indications + df.extent_of_exam + df.findings

# %%
new_data = new_data.to_frame('all')

# %%
new_small_data = new_data[:1000]
new_small_eval_data = new_data[1000:2000]

# %%
train_dataset = datasets.Dataset.from_dict(new_small_data)
val_dataset = datasets.Dataset.from_dict(new_small_eval_data)
my_dataset_dict = datasets.DatasetDict({"train":train_dataset,"test":val_dataset})

# %%
tokenized_train_dataset = train_dataset.map(tokenize_function)
tokenized_train_dataset = tokenized_train_dataset.remove_columns(['all'])

tokenized_eval_dataset = val_dataset.map(tokenize_function)
tokenized_eval_dataset = tokenized_eval_dataset.remove_columns(['all'])

# %%
tokenized_dataset_dict = datasets.DatasetDict({"train":tokenized_train_dataset,"test":tokenized_eval_dataset})

# %%
import numpy as np
import evaluate

metric = evaluate.load("accuracy")

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(output_dir="test_trainer", evaluation_strategy="epoch")

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset_dict['train'],
    eval_dataset=tokenized_dataset_dict['test'],
    compute_metrics=compute_metrics,
)

# %%
trainer.train()

# %% [markdown]
# # Generate random combinations of extent_of_exam and indications

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
# !pwd
# Out:
# /home/jupyter/open_medicine/notebooks

# %%
model_path = '/home/jupyter/open_medicine/notebooks/checkpoint-34500/'

# %%
model2 = AutoModelForCausalLM.from_pretrained(model_path, from_tf= False)

# %%
generator2 = pipeline('text-generation', model=model2, tokenizer=tokenizer)

# %%
prompt_new = (df.indications.map(lambda x: 'INDICATIONS FOR PROCEDURE: ' + x.strip())) + (df.extent_of_exam.map(lambda x: 'Extent of Exam: ' + x.strip()))
prompt_new = prompt_new.map(lambda x: x + ' FINDINGS: ').drop_duplicates().sort_values()

# %%
prompt_new
# Out:
# 721     INDICATIONS FOR PROCEDURE: Abdominal Pain .Ext...
# 1525    INDICATIONS FOR PROCEDURE: Abdominal Pain .Ext...
# 2388    INDICATIONS FOR PROCEDURE: Abdominal Pain .Ext...
# 1610    INDICATIONS FOR PROCEDURE: Abdominal Pain .Ext...
# 797     INDICATIONS FOR PROCEDURE: Abdominal Pain .Ext...
#                               ...
# 3566    INDICATIONS FOR PROCEDURE: ongoing diarhoea in...
# 625     INDICATIONS FOR PROCEDURE: ongoing diarhoea in...
# 623     INDICATIONS FOR PROCEDURE: ongoing diarhoea in...
# 2534    INDICATIONS FOR PROCEDURE: ongoing diarhoea in...
# 205     INDICATIONS FOR PROCEDURE: ongoing diarhoea in...
# Length: 1127, dtype: object

# %%
prompt = (df.indications.map(lambda x: x.strip())  + df.extent_of_exam.map(lambda x: x.strip()) + ' FINDINGS:').drop_duplicates()

# %%
import random
size = 10
prompt_selected = random.sample(range(1125), size)

# %%
findings = [generator2(prompt_new.iloc[i], max_new_tokens = 50, min_new_tokens = 10) for i in prompt_selected]

# %%
def get_findings(text):
    start = 'FINDINGS:'
    return text[text.find(start) + len(start):].strip()

# %%
finding_text = [get_findings(findings[i][0]['generated_text']) for i in range(size)]

 
set(finding_text), len(set(finding_text))
# Out:
# ({'The patient has a polyp in the GOJ which is stalked with an abnormal pit pattern. The oesophageal mucosa appears thickened with a nodular surface, suggestive of an esophageal carcinoid tumor.The patient should be advised to avoid consuming too much sugar, as this can',
#   'The patient has a polyp in the GOJ which is stalked.It has an abnormal pit pattern. The oesophageal mucosa appears thickened with a nodular surface, suggestive of an esophageal carcinoid tumor.The patient should be advised to avoid consuming too much sugar,',
#   'There is a nodule in the GOJ which is stalked. A nodular lesion is seen in the oesophagus, with surrounding erythema and nodularity of the overlying mucosa, suggestive of an esophageal leiomyoma.The patient should be advised to avoid consuming too much',
#   'There is a nodule in the GOJ which is stalked. NA FOLLOW UP: The patient should be advised to avoid consuming too much sugar, as this can increase the risk of bacterial overgrowth in the stomach and increase the risk of polyp growth',
#   'There is a nodule in the third part of the duodenum which is stalked. NA FOLLOW UP: The patient should be advised to avoid consuming too much sugar, as this can increase the risk of bacterial overgrowth in the stomach and increase the risk'},
#  5)

# %%
df_findings = pd.DataFrame({'finding': findings})

# Save the DataFrame as a CSV file
findings_csv = df.to_csv('findings50.csv', index=False)

# %%
l = len("INDICATIONS FOR PROCEDURE: ")

indication_list = [findings[i][0]['generated_text'].split('Extent of Exam: ')[0][l:].strip() for i in range(len(findings))]
extent_list = [findings[i][0]['generated_text'].split('Extent of Exam: ')[1].split('FINDINGS:')[0].strip() for i in range(len(findings))]
finding_list = [findings[i][0]['generated_text'].split('Extent of Exam: ')[1].split('FINDINGS:')[1].strip() for i in range(len(findings))]

gen_1 = pd.DataFrame({'Indication': indication_list, 'Extent of Exam': extent_list, 'Findings': finding_list})

# %%
gen_1['prompt'] =gen_1.Indication + gen_1['Extent of Exam']
gen_1['prompt']
# Out:
# 0                                    Abdominal Pain .D1
# 1                                    Abdominal Pain .D2
# 2                     Abdominal Pain .Failed intubation
# 3                                   Abdominal Pain .GOJ
# 4                            Abdominal Pain .Oesophagus
# 5                               Abdominal Pain .Pylorus
# 6                          Abdominal Pain .Stomach body
# 7         Abdominal Pain Anaemia/Low Iron or VitaminsD1
# 8         Abdominal Pain Anaemia/Low Iron or VitaminsD2
# 9     Abdominal Pain Anaemia/Low Iron or VitaminsFai...
# 10       Abdominal Pain Anaemia/Low Iron or VitaminsGOJ
# 11    Abdominal Pain Anaemia/Low Iron or VitaminsOes...
# 12    Abdominal Pain Anaemia/Low Iron or VitaminsPyl...
# 13    Abdominal Pain Anaemia/Low Iron or VitaminsSto...
# 14                            Abdominal Pain BloatingD1
# 15                            Abdominal Pain BloatingD2
# 16             Abdominal Pain BloatingFailed intubation
# 17                           Abdominal Pain BloatingGOJ
# 18                    Abdominal Pain BloatingOesophagus
# 19                       Abdominal Pain BloatingPylorus
# 20                  Abdominal Pain BloatingStomach body
# 21                           Abdominal Pain DyspepsiaD1
# 22                           Abdominal Pain DyspepsiaD2
# 23            Abdominal Pain DyspepsiaFailed intubation
# 24                          Abdominal Pain DyspepsiaGOJ
# 25                   Abdominal Pain DyspepsiaOesophagus
# 26                      Abdominal Pain DyspepsiaPylorus
# 27                 Abdominal Pain DyspepsiaStomach body
# 28               Abdominal Pain Dysphagia/OdynophagiaD1
# 29               Abdominal Pain Dysphagia/OdynophagiaD2
# 30    Abdominal Pain Dysphagia/OdynophagiaFailed int...
# 31              Abdominal Pain Dysphagia/OdynophagiaGOJ
# 32       Abdominal Pain Dysphagia/OdynophagiaOesophagus
# 33          Abdominal Pain Dysphagia/OdynophagiaPylorus
# 34     Abdominal Pain Dysphagia/OdynophagiaStomach body
# 35                    Abdominal Pain Melaena/Blood PRD1
# 36                    Abdominal Pain Melaena/Blood PRD2
# 37     Abdominal Pain Melaena/Blood PRFailed intubation
# 38                   Abdominal Pain Melaena/Blood PRGOJ
# 39            Abdominal Pain Melaena/Blood PROesophagus
# 40               Abdominal Pain Melaena/Blood PRPylorus
# 41          Abdominal Pain Melaena/Blood PRStomach body
# 42    Abdominal Pain Nausea and/or Vomiting Other- d...
# 43    Abdominal Pain Nausea and/or Vomiting Other- d...
# 44    Abdominal Pain Nausea and/or Vomiting Other- d...
# 45    Abdominal Pain Nausea and/or Vomiting Other- d...
# 46    Abdominal Pain Nausea and/or Vomiting Other- d...
# 47    Abdominal Pain Nausea and/or Vomiting Other- d...
# 48    Abdominal Pain Nausea and/or Vomiting Other- d...
# 49    Abdominal Pain Nausea and/or Vomiting Reflux-l...
# Name: prompt, dtype: object

# %%
gen_1.sort_values(by = 'prompt').reset_index()
# Out:
#     index                                         Indication  \
# 0       0                                   Abdominal Pain .
# 1       1                                   Abdominal Pain .
# 2       2                                   Abdominal Pain .
# 3       3                                   Abdominal Pain .
# 4       4                                   Abdominal Pain .
# 5       5                                   Abdominal Pain .
# 6       6                                   Abdominal Pain .
# 7       7        Abdominal Pain Anaemia/Low Iron or Vitamins
# 8       8        Abdominal Pain Anaemia/Low Iron or Vitamins
# 9       9        Abdominal Pain Anaemia/Low Iron or Vitamins
# 10     10        Abdominal Pain Anaemia/Low Iron or Vitamins
# 11     11        Abdominal Pain Anaemia/Low Iron or Vitamins
# 12     12        Abdominal Pain Anaemia/Low Iron or Vitamins
# 13     13        Abdominal Pain Anaemia/Low Iron or Vitamins
# 14     14                            Abdominal Pain Bloating
# 15     15                            Abdominal Pain Bloating
# 16     16                            Abdominal Pain Bloating
# 17     17                            Abdominal Pain Bloating
# 18     18                            Abdominal Pain Bloating
# 19     19                            Abdominal Pain Bloating
# 20     20                            Abdominal Pain Bloating
# 21     21                           Abdominal Pain Dyspepsia
# 22     22                           Abdominal Pain Dyspepsia
# 23     23                           Abdominal Pain Dyspepsia
# 24     24                           Abdominal Pain Dyspepsia
# 25     25                           Abdominal Pain Dyspepsia
# 26     26                           Abdominal Pain Dyspepsia
# 27     27                           Abdominal Pain Dyspepsia
# 28     28               Abdominal Pain Dysphagia/Odynophagia
# 29     29               Abdominal Pain Dysphagia/Odynophagia
# 30     30               Abdominal Pain Dysphagia/Odynophagia
# 31     31               Abdominal Pain Dysphagia/Odynophagia
# 32     32               Abdominal Pain Dysphagia/Odynophagia
# 33     33               Abdominal Pain Dysphagia/Odynophagia
# 34     34               Abdominal Pain Dysphagia/Odynophagia
# 35     35                    Abdominal Pain Melaena/Blood PR
# 36     36                    Abdominal Pain Melaena/Blood PR
# 37     37                    Abdominal Pain Melaena/Blood PR
# 38     38                    Abdominal Pain Melaena/Blood PR
# 39     39                    Abdominal Pain Melaena/Blood PR
# 40     40                    Abdominal Pain Melaena/Blood PR
# 41     41                    Abdominal Pain Melaena/Blood PR
# 42     42  Abdominal Pain Nausea and/or Vomiting Other- d...
# 43     43  Abdominal Pain Nausea and/or Vomiting Other- d...
# 44     44  Abdominal Pain Nausea and/or Vomiting Other- d...
# 45     45  Abdominal Pain Nausea and/or Vomiting Other- d...
# 46     46  Abdominal Pain Nausea and/or Vomiting Other- d...
# 47     47  Abdominal Pain Nausea and/or Vomiting Other- d...
# 48     48  Abdominal Pain Nausea and/or Vomiting Other- d...
# 49     49  Abdominal Pain Nausea and/or Vomiting Reflux-l...
#
#        Extent of Exam                                           Findings  \
# 0                  D1  There is a nodule in the GOJ which is stalked....
# 1                  D2  There is a nodule in the GOJ which is stalked....
# 2   Failed intubation  There is a nodule in the GOJ which is stalked....
# 3                 GOJ  There is a nodule in the GOJ which is stalked....
# 4          Oesophagus  There is a nodule in the GOJ which is stalked....
# 5             Pylorus  There is a nodule in the GOJ which is stalked....
# 6        Stomach body  There is a nodule in the GOJ which is stalked....
# 7                  D1  There is a nodule in the GOJ which is stalked....
# 8                  D2  There is a nodule in the GOJ which is stalked....
# 9   Failed intubation  There is a nodule in the third part of the duo...
# 10                GOJ  There is a nodule in the GOJ which is stalked....
# 11         Oesophagus  There is a nodule in the GOJ which is stalked....
# 12            Pylorus  There is a nodule in the third part of the duo...
# 13       Stomach body  There is a nodule in the GOJ which is stalked....
# 14                 D1  There is a nodule in the GOJ which is stalked....
# 15                 D2  There is a nodule in the GOJ which is stalked....
# 16  Failed intubation  There is a nodule in the third part of the duo...
# 17                GOJ  There is a nodule in the GOJ which is stalked....
# 18         Oesophagus  There is a nodule in the GOJ which is stalked....
# 19            Pylorus  There is a nodule in the third part of the duo...
# 20       Stomach body  There is a nodule in the GOJ which is stalked....
# 21                 D1  There is a nodule in the GOJ which is stalked....
# 22                 D2  There is a nodule in the GOJ which is stalked....
# 23  Failed intubation  There is a nodule in the third part of the duo...
# 24                GOJ  There is a nodule in the GOJ which is stalked....
# 25         Oesophagus  There is a nodule in the GOJ which is stalked....
# 26            Pylorus  There is a nodule in the GOJ which is stalked....
# 27       Stomach body  There is a nodule in the GOJ which is stalked....
# 28                 D1  There is a nodule in the GOJ which is stalked....
# 29                 D2  There is a nodule in the GOJ which is stalked....
# 30  Failed intubation  There is a nodule in the GOJ which is stalked....
# 31                GOJ  There is a nodule in the GOJ which is stalked....
# 32         Oesophagus  There is a nodule in the GOJ which is stalked....
# 33            Pylorus  There is a nodule in the GOJ which is stalked....
# 34       Stomach body  There is a nodule in the GOJ which is stalked....
# 35                 D1  There is a nodule in the GOJ which is stalked....
# 36                 D2  There is a nodule in the GOJ which is stalked....
# 37  Failed intubation  There is a nodule in the third part of the duo...
# 38                GOJ  There is a nodule in the GOJ which is stalked....
# 39         Oesophagus  There is a nodule in the third part of the duo...
# 40            Pylorus  There is a nodule in the third part of the duo...
# 41       Stomach body  There is a nodule in the GOJ which is stalked....
# 42                 D1  The patient has a polyp in the GOJ which is st...
# 43                 D2  The patient has a polyp in the GOJ which is st...
# 44  Failed intubation  There is a nodule in the third part of the duo...
# 45                GOJ  The patient has a polyp in the GOJ which is st...
# 46         Oesophagus  There is a nodule in the third part of the duo...
# 47            Pylorus  There is a nodule in the third part of the duo...
# 48       Stomach body  There is a nodule in the third part of the duo...
# 49                 D1  The patient has a polyp in the GOJ which is st...
#
#                                                prompt
# 0                                  Abdominal Pain .D1
# 1                                  Abdominal Pain .D2
# 2                   Abdominal Pain .Failed intubation
# 3                                 Abdominal Pain .GOJ
# 4                          Abdominal Pain .Oesophagus
# 5                             Abdominal Pain .Pylorus
# 6                        Abdominal Pain .Stomach body
# 7       Abdominal Pain Anaemia/Low Iron or VitaminsD1
# 8       Abdominal Pain Anaemia/Low Iron or VitaminsD2
# 9   Abdominal Pain Anaemia/Low Iron or VitaminsFai...
# 10     Abdominal Pain Anaemia/Low Iron or VitaminsGOJ
# 11  Abdominal Pain Anaemia/Low Iron or VitaminsOes...
# 12  Abdominal Pain Anaemia/Low Iron or VitaminsPyl...
# 13  Abdominal Pain Anaemia/Low Iron or VitaminsSto...
# 14                          Abdominal Pain BloatingD1
# 15                          Abdominal Pain BloatingD2
# 16           Abdominal Pain BloatingFailed intubation
# 17                         Abdominal Pain BloatingGOJ
# 18                  Abdominal Pain BloatingOesophagus
# 19                     Abdominal Pain BloatingPylorus
# 20                Abdominal Pain BloatingStomach body
# 21                         Abdominal Pain DyspepsiaD1
# 22                         Abdominal Pain DyspepsiaD2
# 23          Abdominal Pain DyspepsiaFailed intubation
# 24                        Abdominal Pain DyspepsiaGOJ
# 25                 Abdominal Pain DyspepsiaOesophagus
# 26                    Abdominal Pain DyspepsiaPylorus
# 27               Abdominal Pain DyspepsiaStomach body
# 28             Abdominal Pain Dysphagia/OdynophagiaD1
# 29             Abdominal Pain Dysphagia/OdynophagiaD2
# 30  Abdominal Pain Dysphagia/OdynophagiaFailed int...
# 31            Abdominal Pain Dysphagia/OdynophagiaGOJ
# 32     Abdominal Pain Dysphagia/OdynophagiaOesophagus
# 33        Abdominal Pain Dysphagia/OdynophagiaPylorus
# 34   Abdominal Pain Dysphagia/OdynophagiaStomach body
# 35                  Abdominal Pain Melaena/Blood PRD1
# 36                  Abdominal Pain Melaena/Blood PRD2
# 37   Abdominal Pain Melaena/Blood PRFailed intubation
# 38                 Abdominal Pain Melaena/Blood PRGOJ
# 39          Abdominal Pain Melaena/Blood PROesophagus
# 40             Abdominal Pain Melaena/Blood PRPylorus
# 41        Abdominal Pain Melaena/Blood PRStomach body
# 42  Abdominal Pain Nausea and/or Vomiting Other- d...
# 43  Abdominal Pain Nausea and/or Vomiting Other- d...
# 44  Abdominal Pain Nausea and/or Vomiting Other- d...
# 45  Abdominal Pain Nausea and/or Vomiting Other- d...
# 46  Abdominal Pain Nausea and/or Vomiting Other- d...
# 47  Abdominal Pain Nausea and/or Vomiting Other- d...
# 48  Abdominal Pain Nausea and/or Vomiting Other- d...
# 49  Abdominal Pain Nausea and/or Vomiting Reflux-l...

# %%
df_fake = pd.concat([df['indications'].map(lambda x: x.strip()), df['extent_of_exam'].map(lambda x: x.strip()), df['findings'].map(lambda x: x.strip())], axis=1)

# %%
df_fake['prompt'] = df.indications.map(lambda x: x.strip()) + df.extent_of_exam.map(lambda x: x.strip())

# %%
df_fake = df_fake.sort_values(by = 'prompt').reset_index()

# %%
df_fake.head()
# Out:
#    index       indications extent_of_exam  \
# 0  31916  Abdominal Pain .             D1
# 1  28528  Abdominal Pain .             D1
# 2  19029  Abdominal Pain .             D1
# 3  11459  Abdominal Pain .             D1
# 4  46456  Abdominal Pain .             D1
#
#                                             findings              prompt
# 0  There is an ulcer in the GOJ which is scarredI...  Abdominal Pain .D1
# 1  Barrett's is present. No loss of aceto-whiteni...  Abdominal Pain .D1
# 2  The patient has a polyp in the second part of ...  Abdominal Pain .D1
# 3                Normal gastroscopy to the duodenum.  Abdominal Pain .D1
# 4  The patient has Barrett's oesophagus. Short se...  Abdominal Pain .D1

# %%
grouped = df_fake.groupby('prompt')['findings'].apply(lambda x: pd.Series(x.values[:3])).unstack()

# Rename the columns
grouped.columns = ['Findings 1', 'Findings 2', 'Findings 3']

# Reset the index
grouped = grouped.reset_index()

# %%
test_gen = gen_1.merge(grouped, on = 'prompt', how = 'left')

# %%
test_gen.drop(columns = ['prompt', 'Findings 3', 'Findings 2'])
# Out:
#                                            Indication     Extent of Exam  \
# 0                                    Abdominal Pain .                 D1
# 1                                    Abdominal Pain .                 D2
# 2                                    Abdominal Pain .  Failed intubation
# 3                                    Abdominal Pain .                GOJ
# 4                                    Abdominal Pain .         Oesophagus
# 5                                    Abdominal Pain .            Pylorus
# 6                                    Abdominal Pain .       Stomach body
# 7         Abdominal Pain Anaemia/Low Iron or Vitamins                 D1
# 8         Abdominal Pain Anaemia/Low Iron or Vitamins                 D2
# 9         Abdominal Pain Anaemia/Low Iron or Vitamins  Failed intubation
# 10        Abdominal Pain Anaemia/Low Iron or Vitamins                GOJ
# 11        Abdominal Pain Anaemia/Low Iron or Vitamins         Oesophagus
# 12        Abdominal Pain Anaemia/Low Iron or Vitamins            Pylorus
# 13        Abdominal Pain Anaemia/Low Iron or Vitamins       Stomach body
# 14                            Abdominal Pain Bloating                 D1
# 15                            Abdominal Pain Bloating                 D2
# 16                            Abdominal Pain Bloating  Failed intubation
# 17                            Abdominal Pain Bloating                GOJ
# 18                            Abdominal Pain Bloating         Oesophagus
# 19                            Abdominal Pain Bloating            Pylorus
# 20                            Abdominal Pain Bloating       Stomach body
# 21                           Abdominal Pain Dyspepsia                 D1
# 22                           Abdominal Pain Dyspepsia                 D2
# 23                           Abdominal Pain Dyspepsia  Failed intubation
# 24                           Abdominal Pain Dyspepsia                GOJ
# 25                           Abdominal Pain Dyspepsia         Oesophagus
# 26                           Abdominal Pain Dyspepsia            Pylorus
# 27                           Abdominal Pain Dyspepsia       Stomach body
# 28               Abdominal Pain Dysphagia/Odynophagia                 D1
# 29               Abdominal Pain Dysphagia/Odynophagia                 D2
# 30               Abdominal Pain Dysphagia/Odynophagia  Failed intubation
# 31               Abdominal Pain Dysphagia/Odynophagia                GOJ
# 32               Abdominal Pain Dysphagia/Odynophagia         Oesophagus
# 33               Abdominal Pain Dysphagia/Odynophagia            Pylorus
# 34               Abdominal Pain Dysphagia/Odynophagia       Stomach body
# 35                    Abdominal Pain Melaena/Blood PR                 D1
# 36                    Abdominal Pain Melaena/Blood PR                 D2
# 37                    Abdominal Pain Melaena/Blood PR  Failed intubation
# 38                    Abdominal Pain Melaena/Blood PR                GOJ
# 39                    Abdominal Pain Melaena/Blood PR         Oesophagus
# 40                    Abdominal Pain Melaena/Blood PR            Pylorus
# 41                    Abdominal Pain Melaena/Blood PR       Stomach body
# 42  Abdominal Pain Nausea and/or Vomiting Other- d...                 D1
# 43  Abdominal Pain Nausea and/or Vomiting Other- d...                 D2
# 44  Abdominal Pain Nausea and/or Vomiting Other- d...  Failed intubation
# 45  Abdominal Pain Nausea and/or Vomiting Other- d...                GOJ
# 46  Abdominal Pain Nausea and/or Vomiting Other- d...         Oesophagus
# 47  Abdominal Pain Nausea and/or Vomiting Other- d...            Pylorus
# 48  Abdominal Pain Nausea and/or Vomiting Other- d...       Stomach body
# 49  Abdominal Pain Nausea and/or Vomiting Reflux-l...                 D1
#
#                                              Findings  \
# 0   There is a nodule in the GOJ which is stalked....
# 1   There is a nodule in the GOJ which is stalked....
# 2   There is a nodule in the GOJ which is stalked....
# 3   There is a nodule in the GOJ which is stalked....
# 4   There is a nodule in the GOJ which is stalked....
# 5   There is a nodule in the GOJ which is stalked....
# 6   There is a nodule in the GOJ which is stalked....
# 7   There is a nodule in the GOJ which is stalked....
# 8   There is a nodule in the GOJ which is stalked....
# 9   There is a nodule in the third part of the duo...
# 10  There is a nodule in the GOJ which is stalked....
# 11  There is a nodule in the GOJ which is stalked....
# 12  There is a nodule in the third part of the duo...
# 13  There is a nodule in the GOJ which is stalked....
# 14  There is a nodule in the GOJ which is stalked....
# 15  There is a nodule in the GOJ which is stalked....
# 16  There is a nodule in the third part of the duo...
# 17  There is a nodule in the GOJ which is stalked....
# 18  There is a nodule in the GOJ which is stalked....
# 19  There is a nodule in the third part of the duo...
# 20  There is a nodule in the GOJ which is stalked....
# 21  There is a nodule in the GOJ which is stalked....
# 22  There is a nodule in the GOJ which is stalked....
# 23  There is a nodule in the third part of the duo...
# 24  There is a nodule in the GOJ which is stalked....
# 25  There is a nodule in the GOJ which is stalked....
# 26  There is a nodule in the GOJ which is stalked....
# 27  There is a nodule in the GOJ which is stalked....
# 28  There is a nodule in the GOJ which is stalked....
# 29  There is a nodule in the GOJ which is stalked....
# 30  There is a nodule in the GOJ which is stalked....
# 31  There is a nodule in the GOJ which is stalked....
# 32  There is a nodule in the GOJ which is stalked....
# 33  There is a nodule in the GOJ which is stalked....
# 34  There is a nodule in the GOJ which is stalked....
# 35  There is a nodule in the GOJ which is stalked....
# 36  There is a nodule in the GOJ which is stalked....
# 37  There is a nodule in the third part of the duo...
# 38  There is a nodule in the GOJ which is stalked....
# 39  There is a nodule in the third part of the duo...
# 40  There is a nodule in the third part of the duo...
# 41  There is a nodule in the GOJ which is stalked....
# 42  The patient has a polyp in the GOJ which is st...
# 43  The patient has a polyp in the GOJ which is st...
# 44  There is a nodule in the third part of the duo...
# 45  The patient has a polyp in the GOJ which is st...
# 46  There is a nodule in the third part of the duo...
# 47  There is a nodule in the third part of the duo...
# 48  There is a nodule in the third part of the duo...
# 49  The patient has a polyp in the GOJ which is st...
#
#                                            Findings 1
# 0   There is an ulcer in the GOJ which is scarredI...
# 1                 Normal gastroscopy to the duodenum.
# 2   The patient has a 8mm nodule in the fundus whi...
# 3   The patient has inflammation in the second par...
# 4   The patient has a 6mm nodule in the third part...
# 5                 Normal gastroscopy to the duodenum.
# 6   The patient has a polyp in the second part of ...
# 7                 Normal gastroscopy to the duodenum.
# 8   There is an ulcer in the duodenal bulb which i...
# 9   The patient has a 8mm nodule in the third part...
# 10  There is an ulcer in the oesophagus at 30 cm w...
# 11                Normal gastroscopy to the duodenum.
# 12                Normal gastroscopy to the duodenum.
# 13  The patient has inflammation in the third part...
# 14  The patient has a stricture in the fundus whic...
# 15  Not the most convincing oesophageal trachealis...
# 16  The length of the segment affected by eosinoph...
# 17                Normal gastroscopy to the duodenum.
# 18                Normal gastroscopy to the duodenum.
# 19  There is inflammation in the third part of the...
# 20                          Small hiatus hernia only.
# 21  The patient has inflammation in the second par...
# 22               Lax cardia with small hiatus hernia.
# 23  The patient has inflammation in the second par...
# 24  There is a stricture in the body which is ulce...
# 25                Normal gastroscopy to the duodenum.
# 26  The patient has a polyp in the duodenal bulb w...
# 27  The patient has a 7mm nodule in the duodenal b...
# 28                              Small hiatus hernia..
# 29                Normal gastroscopy to the duodenum.
# 30                Normal gastroscopy to the duodenum.
# 31  Trachealisation of the oesophagus is observed....
# 32  There is inflammation in the antrum which is m...
# 33        At 18cm two inlet patches  were also seen..
# 34  As an incidental finding she also has a cervic...
# 35  The oesophagus demonstrates concentric rings, ...
# 36  No evidence of inlet patch on careful inspecti...
# 37  There is a polyp in the stomach which is stalk...
# 38                Normal gastroscopy to the duodenum.
# 39                Normal gastroscopy to the duodenum.
# 40  There is a stricture in the stomach which is i...
# 41                                    Hiatus hernia..
# 42                Normal gastroscopy to the duodenum.
# 43  There is a stricture in the antrum which is un...
# 44                Normal gastroscopy to the duodenum.
# 45                Normal gastroscopy to the duodenum.
# 46                Normal gastroscopy to the duodenum.
# 47  There is a nodule in the third part of the duo...
# 48  There is a polyp in the stomach which is stalk...
# 49  There is a polyp in the body which is stalked ...

# %%
# Out:
# ('Abdominal Pain .D1', 'Abdominal Pain .D1')

# %%
import spacy

nlp = spacy.load('en_core_web_md') # Load pre-trained word embedding model

def get_cosine_similarity(text1, text2):
    doc1 = nlp(text1)
    doc2 = nlp(text2)
    return doc1.similarity(doc2) # Compute cosine similarity between two documents

# # Example usage
# text1 = "The patient has mild inflammation in the stomach"
# text2 = "There is mild inflammation in the patient's stomach"
# similarity_score = get_cosine_similarity(text1, text2)
# print(similarity_score)

# %%
get_cosine_similarity(test_gen.Findings[0], test_gen['Findings 2'][20])
# Out:
# 0.7808509741643225
